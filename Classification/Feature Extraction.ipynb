# %% [markdown]
# <h1 style = "font-size:3rem;color:DarkCyan">Feature Comparison between audio files</h1>

# %%
#import libraries
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import librosa, librosa.display 
import IPython.display as ipd
import scipy
import os
import pandas as pd

import sklearn

# %%
# import dataset, in this case different percussion sounds

filenames = os.listdir('./data')
print(f'Number of audio files: {len(filenames)} ')
# Out:
# Number of audio files: 167

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Extracting features</h2>
#
# - Extracting features (Bandwidth, central spectroid, and zero-crossing rate) for each audio file, and store in a NxF matrix
# - Giving a label

# %%
def extract_features(data):
    return [
        np.mean(librosa.feature.spectral_centroid(y = data)),
        np.mean(librosa.feature.spectral_bandwidth(y = data)),
        np.mean(librosa.feature.spectral_flatness(y = data)),
        np.mean(librosa.feature.spectral_rolloff(y = data)),
        np.mean(librosa.feature.mfcc(y = data)),
        np.mean(librosa.feature.spectral_contrast(y = data)),
        np.mean(librosa.feature.zero_crossing_rate(y = data)),
        np.mean(librosa.feature.rms(y = data)),
        np.mean(librosa.feature.tempogram(y=data))
    ]

# %%
def get_label(name):
    if name.find('clap') != -1:
        return 0
    elif name.find('cymbal') != -1:
        return 1
    elif name.find('kick') != -1:
        return 2
    else:
        return 3

# %%
sr = 48000
feature_names = ['sc','sbw','sf', 'sr', 'mfcc', 'scon', 'zcr', 'rms', 'tg']
amount_of_features = len(feature_names)

features = np.zeros((len(filenames), amount_of_features))
labels = np.zeros(len(filenames))

idx = 0

for name in filenames:
    data, dummy = librosa.load('./data/'+name, sr = sr, mono=True)
    
    # fill prediction array with correct label 
    labels[idx] = get_label(name)
    
    # extract features
    features[idx] = extract_features(data)
    
    idx +=1

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Plotting features</h2>

# %%
f_dict = {'sc' : 0, 'sbw' : 1, 'sf': 2, 'sr' : 3, 'mfcc' : 4, 'scon' : 5,'zcr' : 6, 'rms': 7, 'tg' : 8}
# choose three features

f1 = 'mfcc'
f2 = 'tg'
f3 = 'sbw'

# plot the features
# %matplotlib notebook
#fig = plt.figure(figsize = (15, 9))
ax = plt.axes(projection ="3d")
ax.scatter3D(features[np.where(labels == 0),f_dict[f1]], features[np.where(labels == 0),f_dict[f2]], features[np.where(labels == 0),f_dict[f3]], label = 'clap')
ax.scatter3D(features[np.where(labels == 1),f_dict[f1]], features[np.where(labels == 1),f_dict[f2]], features[np.where(labels == 1),f_dict[f3]], label = 'cymbal')
ax.scatter3D(features[np.where(labels == 2),f_dict[f1]], features[np.where(labels == 2),f_dict[f2]], features[np.where(labels == 2),f_dict[f3]], label = 'kick')
ax.scatter3D(features[np.where(labels == 3),f_dict[f1]], features[np.where(labels == 3),f_dict[f2]], features[np.where(labels == 3),f_dict[f3]], label = 'snare')


#plt.scatter(feature2[:,0], feature2[:,1])
plt.title('Scatter plot of computed means')
ax.set_xlabel(f1)
ax.set_ylabel(f2)
ax.set_zlabel(f3)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Scale features & plot again</h2>
#
# - scale features for better comparison (after this step features will present zero mean and unit variance)

# %%
print('Mean and std before scaling',np.mean(features, axis=0),np.std(features, axis=0))

features = sklearn.preprocessing.scale(features)

print('Mean and std after scaling',np.mean(features, axis=0),np.std(features, axis=0))
# Out:
# Mean and std before scaling [ 1.60794752e+03  1.46614746e+03  1.78297782e-01  3.14417057e+03
#  -1.81131847e+01  2.06562447e+01  8.94566901e-02  5.07136850e-02
#   8.48584916e-02] [8.95756004e+02 7.02382780e+02 2.59673601e-01 1.77189515e+03
#  9.59610701e+00 2.78300000e+00 6.32586899e-02 8.92786962e-02
#  8.92904814e-02]
# Mean and std after scaling [-9.67954924e-16 -3.90240069e-16  7.97765048e-18  4.21485867e-16
#   2.88857428e-16  1.58090440e-15 -5.63753967e-16  4.48742839e-17
#  -5.24530519e-16] [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %%
# plot the features
# %matplotlib notebook
#fig = plt.figure(figsize = (15, 9))
ax = plt.axes(projection ="3d")
ax.scatter3D(features[np.where(labels == 0),f_dict[f1]], features[np.where(labels == 0),f_dict[f2]], features[np.where(labels == 0),f_dict[f3]], label = 'clap')
ax.scatter3D(features[np.where(labels == 1),f_dict[f1]], features[np.where(labels == 1),f_dict[f2]], features[np.where(labels == 1),f_dict[f3]], label = 'cymbal')
ax.scatter3D(features[np.where(labels == 2),f_dict[f1]], features[np.where(labels == 2),f_dict[f2]], features[np.where(labels == 2),f_dict[f3]], label = 'kick')
ax.scatter3D(features[np.where(labels == 3),f_dict[f1]], features[np.where(labels == 3),f_dict[f2]], features[np.where(labels == 3),f_dict[f3]], label = 'snare')


#plt.scatter(feature2[:,0], feature2[:,1])
plt.title('Scatter plot of computed means')
ax.set_xlabel(f1)
ax.set_ylabel(f2)
ax.set_zlabel(f3)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Correlation Matrix</h2>

# %%
df = pd.DataFrame(features, columns=feature_names)
corr = df.corr()
corr.style.format(na_rep='MISS', precision=3)  
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
corr.style.format(na_rep='MISS', precision=3) 
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 )
# Out:
# <style type="text/css">
# #T_2ae98_row0_col0, #T_2ae98_row0_col1, #T_2ae98_row0_col2, #T_2ae98_row0_col3, #T_2ae98_row0_col4, #T_2ae98_row0_col5, #T_2ae98_row0_col6, #T_2ae98_row0_col7, #T_2ae98_row0_col8, #T_2ae98_row1_col1, #T_2ae98_row1_col2, #T_2ae98_row1_col3, #T_2ae98_row1_col4, #T_2ae98_row1_col5, #T_2ae98_row1_col6, #T_2ae98_row1_col7, #T_2ae98_row1_col8, #T_2ae98_row2_col2, #T_2ae98_row2_col3, #T_2ae98_row2_col4, #T_2ae98_row2_col5, #T_2ae98_row2_col6, #T_2ae98_row2_col7, #T_2ae98_row2_col8, #T_2ae98_row3_col3, #T_2ae98_row3_col4, #T_2ae98_row3_col5, #T_2ae98_row3_col6, #T_2ae98_row3_col7, #T_2ae98_row3_col8, #T_2ae98_row4_col4, #T_2ae98_row4_col5, #T_2ae98_row4_col6, #T_2ae98_row4_col7, #T_2ae98_row4_col8, #T_2ae98_row5_col5, #T_2ae98_row5_col6, #T_2ae98_row5_col7, #T_2ae98_row5_col8, #T_2ae98_row6_col6, #T_2ae98_row6_col7, #T_2ae98_row6_col8, #T_2ae98_row7_col7, #T_2ae98_row7_col8, #T_2ae98_row8_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_2ae98_row1_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_2ae98_row2_col0, #T_2ae98_row3_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_2ae98_row2_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2ae98_row3_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_2ae98_row3_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_2ae98_row4_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_2ae98_row4_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_2ae98_row4_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_2ae98_row4_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_2ae98_row5_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_2ae98_row5_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_2ae98_row5_col2, #T_2ae98_row6_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2ae98_row5_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_2ae98_row5_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_2ae98_row6_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_2ae98_row6_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_2ae98_row6_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_2ae98_row6_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_2ae98_row6_col5 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_2ae98_row7_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_2ae98_row7_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_2ae98_row7_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_2ae98_row7_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2ae98_row7_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_2ae98_row7_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_2ae98_row7_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_2ae98_row8_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_2ae98_row8_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_2ae98_row8_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_2ae98_row8_col3 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_2ae98_row8_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_2ae98_row8_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_2ae98_row8_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_2ae98_row8_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# </style>
# <table id="T_2ae98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ae98_level0_col0" class="col_heading level0 col0" >sc</th>
#       <th id="T_2ae98_level0_col1" class="col_heading level0 col1" >sbw</th>
#       <th id="T_2ae98_level0_col2" class="col_heading level0 col2" >sf</th>
#       <th id="T_2ae98_level0_col3" class="col_heading level0 col3" >sr</th>
#       <th id="T_2ae98_level0_col4" class="col_heading level0 col4" >mfcc</th>
#       <th id="T_2ae98_level0_col5" class="col_heading level0 col5" >scon</th>
#       <th id="T_2ae98_level0_col6" class="col_heading level0 col6" >zcr</th>
#       <th id="T_2ae98_level0_col7" class="col_heading level0 col7" >rms</th>
#       <th id="T_2ae98_level0_col8" class="col_heading level0 col8" >tg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ae98_level0_row0" class="row_heading level0 row0" >sc</th>
#       <td id="T_2ae98_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2ae98_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_2ae98_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_2ae98_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_2ae98_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_2ae98_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_2ae98_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_2ae98_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_2ae98_row0_col8" class="data row0 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ae98_level0_row1" class="row_heading level0 row1" >sbw</th>
#       <td id="T_2ae98_row1_col0" class="data row1 col0" >0.915217</td>
#       <td id="T_2ae98_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_2ae98_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_2ae98_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_2ae98_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_2ae98_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_2ae98_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_2ae98_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_2ae98_row1_col8" class="data row1 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ae98_level0_row2" class="row_heading level0 row2" >sf</th>
#       <td id="T_2ae98_row2_col0" class="data row2 col0" >-0.687226</td>
#       <td id="T_2ae98_row2_col1" class="data row2 col1" >-0.721321</td>
#       <td id="T_2ae98_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_2ae98_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_2ae98_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_2ae98_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_2ae98_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_2ae98_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_2ae98_row2_col8" class="data row2 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ae98_level0_row3" class="row_heading level0 row3" >sr</th>
#       <td id="T_2ae98_row3_col0" class="data row3 col0" >0.979052</td>
#       <td id="T_2ae98_row3_col1" class="data row3 col1" >0.967693</td>
#       <td id="T_2ae98_row3_col2" class="data row3 col2" >-0.681367</td>
#       <td id="T_2ae98_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_2ae98_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_2ae98_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_2ae98_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_2ae98_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_2ae98_row3_col8" class="data row3 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ae98_level0_row4" class="row_heading level0 row4" >mfcc</th>
#       <td id="T_2ae98_row4_col0" class="data row4 col0" >-0.285682</td>
#       <td id="T_2ae98_row4_col1" class="data row4 col1" >-0.346253</td>
#       <td id="T_2ae98_row4_col2" class="data row4 col2" >-0.100810</td>
#       <td id="T_2ae98_row4_col3" class="data row4 col3" >-0.318451</td>
#       <td id="T_2ae98_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_2ae98_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_2ae98_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_2ae98_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_2ae98_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ae98_level0_row5" class="row_heading level0 row5" >scon</th>
#       <td id="T_2ae98_row5_col0" class="data row5 col0" >0.397573</td>
#       <td id="T_2ae98_row5_col1" class="data row5 col1" >0.333714</td>
#       <td id="T_2ae98_row5_c

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Dimensionality Reduction</h2>

# %%
# from the correlation matrix can be seen that there are 
# spectral centroid, bandwidth, and roll-off are strongly correrelated 
# with other features, these can be discarded to simplify the model
features_to_exclude = ['sc', 'sbw', 'sr']
print(np.shape(features))
indexes = np.where(np.isin(feature_names,features_to_exclude))
print(indexes)

selected_features = []
new_feature_names =[]
for i in range(0,amount_of_features):
    if not np.isin(i,indexes):
        selected_features.append(features[:,i])
        new_feature_names.append(feature_names[i])
        
#features = features[:,2:]
selected_features= np.array(selected_features).T
print(np.shape(selected_features))
print(new_feature_names)
#feature_names = feature_names[2:]
# Out:
# (167, 9)
# (array([0, 1, 3], dtype=int64),)
# (167, 6)
# ['sf', 'mfcc', 'scon', 'zcr', 'rms', 'tg']

# %% [markdown]
# <h2 style = "font-size:2rem;color:DarkCyan">Save Features</h2>
#
# - scale features for better comparison (after this step features will present zero mean and unit variance)

# %%
#merging everything into a single data structure
dataset = pd.DataFrame(selected_features)
dataset.columns = new_feature_names #naming the features
dataset['label'] = labels
dataset['filename'] = filenames

#we can save the dataset to a file to resume working without re-computing the features (unless you want to change them)
dataset.to_csv('dataset.csv')
dataset
# Out:
#            sf      mfcc      scon       zcr       rms        tg  label  \
# 0   -0.650937  0.201820 -0.181805  2.359166 -0.087440  0.422940    0.0
# 1   -0.455283  0.319636 -0.156507  1.448470  0.460283 -0.815594    0.0
# 2   -0.582337  0.004219 -0.096929  1.530512  0.112806 -0.552268    0.0
# 3   -0.481064 -1.139505  0.943533  2.719303  0.093284  0.711343    0.0
# 4   -0.677210 -1.122057  0.161869  0.490405 -0.428324 -0.130251    0.0
# ..        ...       ...       ...       ...       ...       ...    ...
# 162 -0.551290 -0.087366  0.171507  1.413513 -0.314272 -0.779622    3.0
# 163 -0.601877 -0.097283 -0.141917  0.905417 -0.293384 -0.516386    3.0
# 164 -0.628628 -0.308812  0.533378  0.223181 -0.347412 -0.759175    3.0
# 165 -0.603429 -0.261414 -0.104417  0.660124 -0.320820 -0.642373    3.0
# 166 -0.545701 -0.235714  0.440560  1.306093 -0.346581 -0.633840    3.0
#
#          filename
# 0      clap00.wav
# 1      clap01.wav
# 2      clap02.wav
# 3      clap03.wav
# 4      clap04.wav
# ..            ...
# 162  snare_37.wav
# 163  snare_38.wav
# 164  snare_39.wav
# 165  snare_40.wav
# 166  snare_41.wav
#
# [167 rows x 8 columns]
